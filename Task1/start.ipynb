# %%
import os
from google import genai
from dotenv import load_dotenv, find_dotenv

env_file_path = find_dotenv()

print(env_file_path)

is_loaded = load_dotenv(env_file_path, override=True)

print("API Key Loaded:", is_loaded)

my_api_key = os.getenv("GEMINI_API_KEY")
# print("My API Key:", my_api_key)
# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()



response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Hey Gemini!"
)
print(response.text)
# Out:
# /home/ashok/llms_ai_agents/.env
# API Key Loaded: True
# My API Key: AIzaSyBjb0HJoR4aCGd_5x9mlf9dooNNKFTieBg
# Hello! How can I help you today?
